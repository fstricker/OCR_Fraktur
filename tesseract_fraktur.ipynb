# %%
import sys
# !{sys.executable} -m pip install Pillow
# !{sys.executable} -m pip install pytesseract
#!{sys.executable} -m pip install pdf2image (useful when converting pdf to img/png)
# Out:
# ...
# WARNING: You are using pip version 20.1.1; however, version 20.2.3 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.6/bin/python3.6 -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 20.1.1; however, version 20.2.3 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.6/bin/python3.6 -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 20.1.1; however, version 20.2.3 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.6/bin/python3.6 -m pip install --upgrade pip' command.

# %%
try:    
    from PIL import Image
except ImportError:
    import Image
import pytesseract
import urllib.request

# %%
#just to test if tesseract works
#print(pytesseract.image_to_string(Image.open('tests/data/test.png')))

# %%
link = 'http://www.klosterlausnitz-regional.de/Kurwesen/Klosterwald/Galerie/slides/1940-07-20_Gauzeitung.jpg'

# %%
urllib.request.urlretrieve(link, "tests/gauschrift.jpg")
# Out:
# ('tests/gauschrift.jpg', <http.client.HTTPMessage at 0x1118e05c0>)

# %%
print(pytesseract.image_to_string(Image.open('tests/gauschrift.jpg'), lang='script/Fraktur'))
# Out:
# Sonnabend, den 20. Juil
#
#
#
# igorganiſations leite
# i itiden y E Seo)
#
# _dem Jenaer 1
# Leitung “ſeines Dirigenten .-
# find 7
#
# bend |
# er“ den
#
#
#
#
#
#
#
#
# Verwind:
# zahlreijen Gäſten ſaß
# des leider
# Kreisorganiſationsleiter Pg. Willy : Mä
# th es; Oberbürgermeiſter Pg. S< mi,
# Jena; Landrat Pg, Dr. Hoffmann -Stadi
# roda, den Chefarzt des Reſervelazaretts u
# Bürgermeiſter Pg. Wurliher aus Eiſen-
# bezg, Büzgerméiter Pa, Weiſe aus Herms
# dorf und Mitglieder des Kreisſtabes ſowie
# ſämtliche Vertréter der Partei und Gemejnôe
# aus Bas Kloſterlausnib.
#
# Mit dem Füßrergruß leitete Ortsgruppen-
# leer Po Mattes den Abend ein. Jn
# - unſeren Herzen, ſo führte er weiter aus,
# flingt no< der Marſchtritt jener Soldaten
# wider, die durc den Einſah ihres Lebens und
# ihrer ‘Gefundheit unſerer Nation den Steg
# über Frankreich erringen halfen. Unſer größ-
# es Beittebeit iſt es, ihnen in der Heimat die
# Danfbarkeit, die wir ihuen ſchulden ‘zu be-
# weiſen. :
#
# ...
